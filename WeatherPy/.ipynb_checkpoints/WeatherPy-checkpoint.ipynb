# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Import today's date in mm/dd/yyyy format
today = date.today()
today = today.strftime("%m/%d/%Y")

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=105260ea8fd02c13bcdc1e7b381de81b"
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vao
# Processing Record 2 of Set 1 | honningsvag
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | tatarsk
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | esperance
# Processing Record 8 of Set 1 | kamskiye polyany
# Processing Record 9 of Set 1 | natal
# Processing Record 10 of Set 1 | storforshei
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | nyurba
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | belushya guba
# Processing Record 15 of Set 1 | yendi
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | krutinka
# Processing Record 20 of Set 1 | iqaluit
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | dokri
# Processing Record 23 of Set 1 | oriximina
# Processing Record 24 of Set 1 | ahuimanu
# Processing Record 25 of Set 1 | pombas
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | te anau
# Processing Record 28 of Set 1 | la primavera
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | jiddah
# Processing Record 33 of Set 1 | mys shmidta
# Processing Record 34 of Set 1 | hovd
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | attawapiskat
# Processing Record 39 of Set 1 | berlevag
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | champerico
# Processing Record 42 of Set 1 | chernyshevskiy
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | yatou
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | nizhneyansk
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | grand river south east
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | port alfred
# Processing Record 0 of Set 2 | lata
# Processing Record 1 of Set 2 | san pedro
# Processing Record 2 of Set 2 | ola
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | pogranichnyy
# Processing Record 5 of Set 2 | estacion coahuila
# Processing Record 6 of Set 2 | turi
# Processing Record 7 of Set 2 | tura
# Processing Record 8 of Set 2 | hobyo
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | rikitea
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | kamenka
# Processing Record 13 of Set 2 | provideniya
# Processing Record 14 of Set 2 | teya
# Processing Record 15 of Set 2 | calvillo
# Processing Record 16 of Set 2 | saint-pierre
# Processing Record 17 of Set 2 | nabire
# Processing Record 18 of Set 2 | nishihara
# Processing Record 19 of Set 2 | gastello
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | barawe
# Processing Record 23 of Set 2 | los llanos de aridane
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | acarau
# Processing Record 26 of Set 2 | vostok
# Processing Record 27 of Set 2 | santa maria
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | valpacos
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | illoqqortoormiut
# Processing Record 32 of Set 2 | terebovlya
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | oktyabrskiy
# Processing Record 36 of Set 2 | north bend
# Processing Record 37 of Set 2 | lazaro cardenas
# Processing Record 38 of Set 2 | kloulklubed
# Processing Record 39 of Set 2 | dzerzhinsk
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | garissa
# Processing Record 42 of Set 2 | nouadhibou
# Processing Record 43 of Set 2 | sitka
# Processing Record 44 of Set 2 | kodinsk
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | napanee
# Processing Record 48 of Set 2 | wangqing
# Processing Record 49 of Set 2 | kapaa
# Processing Record 0 of Set 3 | bambous virieux
# Processing Record 1 of Set 3 | show low
# Processing Record 2 of Set 3 | mount isa
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | maceio
# Processing Record 5 of Set 3 | caravelas
# Processing Record 6 of Set 3 | tadepallegudem
# Processing Record 7 of Set 3 | achacachi
# Processing Record 8 of Set 3 | rungata
# Processing Record 9 of Set 3 | kasimov
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | saint-francois
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | pavlodar
# Processing Record 16 of Set 3 | batagay
# Processing Record 17 of Set 3 | buenos aires
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | vryburg
# Processing Record 20 of Set 3 | umm lajj
# Processing Record 21 of Set 3 | novelda
# Processing Record 22 of Set 3 | busselton
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | salalah
# Processing Record 26 of Set 3 | alpena
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | taolanaro
# Processing Record 29 of Set 3 | santa rosalia
# Processing Record 30 of Set 3 | baloda
# Processing Record 31 of Set 3 | sao felix do xingu
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | tazovskiy
# Processing Record 34 of Set 3 | bubaque
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | aranos
# Processing Record 38 of Set 3 | ferrol
# Processing Record 39 of Set 3 | mortka
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | pervomayskoye
# Processing Record 42 of Set 3 | necochea
# Processing Record 43 of Set 3 | torrington
# Processing Record 44 of Set 3 | algiers
# Processing Record 45 of Set 3 | kendari
# Processing Record 46 of Set 3 | nuuk
# Processing Record 47 of Set 3 | arman
# Processing Record 48 of Set 3 | chifeng
# Processing Record 49 of Set 3 | port augusta
# Processing Record 0 of Set 4 | husavik
# Processing Record 1 of Set 4 | vardo
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | gobabis
# Processing Record 4 of Set 4 | bonthe
# Processing Record 5 of Set 4 | sobolevo
# Processing Record 6 of Set 4 | tarime
# Processing Record 7 of Set 4 | poum
# Processing Record 8 of Set 4 | revelstoke
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | margate
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | northam
# Processing Record 14 of Set 4 | sambava
# Processing Record 15 of Set 4 | nurota
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | katyuzhanka
# Processing Record 18 of Set 4 | sentyabrskiy
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | sibu
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | mason city
# Processing Record 24 of Set 4 | balabac
# Processing Record 25 of Set 4 | alausi
# Processing Record 26 of Set 4 | erzin
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | port elizabeth
# Processing Record 29 of Set 4 | rameshki
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | petropavlovka
# Processing Record 32 of Set 4 | aden
# Processing Record 33 of Set 4 | anuradhapura
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | troitsko-pechorsk
# Processing Record 36 of Set 4 | pacific grove
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | bur gabo
# Processing Record 40 of Set 4 | pak chong
# Processing Record 41 of Set 4 | fort nelson
# Processing Record 42 of Set 4 | borogontsy
# Processing Record 43 of Set 4 | nizwa
# Processing Record 44 of Set 4 | norman wells
# Processing Record 45 of Set 4 | kanchanaburi
# Processing Record 46 of Set 4 | nikolskoye
# Processing Record 47 of Set 4 | cobija
# Processing Record 48 of Set 4 | balkhash
# Processing Record 49 of Set 4 | otjimbingwe
# Processing Record 0 of Set 5 | upernavik
# Processing Record 1 of Set 5 | buqayq
# Processing Record 2 of Set 5 | bonnyville
# Processing Record 3 of Set 5 | da nang
# Processing Record 4 of Set 5 | lengshuijiang
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | mouzouras
# Processing Record 7 of Set 5 | yumen
# Processing Record 8 of Set 5 | herat
# Processing Record 9 of Set 5 | clara
# Processing Record 10 of Set 5 | tilichiki
# Processing Record 11 of Set 5 | limon
# Processing Record 12 of Set 5 | winslow
# Processing Record 13 of Set 5 | lorengau
# Processing Record 14 of Set 5 | samusu
# Processing Record 15 of Set 5 | sibuco
# Processing Record 16 of Set 5 | inhuma
# Processing Record 17 of Set 5 | paragominas
# Processing Record 18 of Set 5 | hilo
# Processing Record 19 of Set 5 | nioro
# Processing Record 20 of Set 5 | luanda
# Processing Record 21 of Set 5 | gaoual
# Processing Record 22 of Set 5 | kieta
# Processing Record 23 of Set 5 | vanimo
# Processing Record 24 of Set 5 | ojinaga
# Processing Record 25 of Set 5 | grand centre
# Processing Record 26 of Set 5 | bossangoa
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | ayagoz
# Processing Record 30 of Set 5 | la cruz
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | salinopolis
# Processing Record 36 of Set 5 | sao filipe
# Processing Record 37 of Set 5 | halalo
# Processing Record 38 of Set 5 | ponta pora
# Processing Record 39 of Set 5 | san juan
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | mantua
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 43 of Set 5 | uvinza
# Processing Record 44 of Set 5 | tsihombe
# Processing Record 45 of Set 5 | buzdyak
# Processing Record 46 of Set 5 | iroquois falls
# Processing Record 47 of Set 5 | norfolk
# Processing Record 48 of Set 5 | sukhobuzimskoye
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 0 of Set 6 | ca mau
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | yerbogachen
# Processing Record 3 of Set 6 | ferkessedougou
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | cherskiy
# Processing Record 6 of Set 6 | marsa matruh
# Processing Record 7 of Set 6 | yambio
# Processing Record 8 of Set 6 | koulikoro
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | duki
# Processing Record 11 of Set 6 | saint-louis
# Processing Record 12 of Set 6 | agadez
# Processing Record 13 of Set 6 | itarema
# Processing Record 14 of Set 6 | vaitupu
# Processing Record 15 of Set 6 | salisbury
# Processing Record 16 of Set 6 | biggar
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | khor
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 6 | nome
# Processing Record 22 of Set 6 | isla vista
# Processing Record 23 of Set 6 | barentsburg
# Processing Record 24 of Set 6 | trinidad
# Processing Record 25 of Set 6 | hangu
# Processing Record 26 of Set 6 | meyungs
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | tacadang
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | komsomolskiy
# Processing Record 31 of Set 6 | hofn
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | lagos
# Processing Record 34 of Set 6 | loncoche
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | maloshuyka
# Processing Record 37 of Set 6 | almeirim
# Processing Record 38 of Set 6 | allada
# Processing Record 39 of Set 6 | iquitos
# Processing Record 40 of Set 6 | viligili
# Processing Record 41 of Set 6 | aflu
# Processing Record 42 of Set 6 | chisindia
# Processing Record 43 of Set 6 | bolungarvik
# Processing Record 44 of Set 6 | college
# Processing Record 45 of Set 6 | tebingtinggi
# Processing Record 46 of Set 6 | ekhabi
# Processing Record 47 of Set 6 | bahawalpur
# Processing Record 48 of Set 6 | nemuro
# Processing Record 49 of Set 6 | broome
# Processing Record 0 of Set 7 | tiksi
# Processing Record 1 of Set 7 | vanavara
# Processing Record 2 of Set 7 | umzimvubu
# Processing Record 3 of Set 7 | tautira
# Processing Record 4 of Set 7 | zhigansk
# Processing Record 5 of Set 7 | amderma
# Processing Record 6 of Set 7 | mount gambier
# Processing Record 7 of Set 7 | ngunguru
# Processing Record 8 of Set 7 | mirnyy
# Processing Record 9 of Set 7 | plettenberg bay
# Processing Record 10 of Set 7 | khudumelapye
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | jumla
# Processing Record 13 of Set 7 | grants
# Processing Record 14 of Set 7 | mahesana
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | sistranda
# Processing Record 17 of Set 7 | augusto correa
# Processing Record 18 of Set 7 | mbandaka
# Processing Record 19 of Set 7 | billings
# Processing Record 20 of Set 7 | adre
# Processing Record 21 of Set 7 | udachnyy
# Processing Record 22 of Set 7 | bozhou
# Processing Record 23 of Set 7 | kismayo
# Processing Record 24 of Set 7 | guarapari
# Processing Record 25 of Set 7 | cheyenne
# Processing Record 26 of Set 7 | qaqortoq
# Processing Record 27 of Set 7 | victoria
# Processing Record 28 of Set 7 | coquimbo
# Processing Record 29 of Set 7 | lompoc
# Processing Record 30 of Set 7 | baghdad
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | laurel
# Processing Record 15 of Set 10 | aksarka
# Processing Record 16 of Set 10 | caidian
# Processing Record 17 of Set 10 | olinda
# Processing Record 18 of Set 10 | bastrop
# Processing Record 19 of Set 10 | belaya gora
# Processing Record 20 of Set 10 | curuca
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | pamatawan
# Processing Record 23 of Set 10 | maciel
# Processing Record 24 of Set 10 | chulman
# Processing Record 25 of Set 10 | bataipora
# Processing Record 26 of Set 10 | grand gaube
# Processing Record 27 of Set 10 | bolama
# Processing Record 28 of Set 10 | praia
# Processing Record 29 of Set 10 | cozumel
# Processing Record 30 of Set 10 | marmande
# Processing Record 31 of Set 10 | mandalgovi
# Processing Record 32 of Set 10 | abu kamal
# Processing Record 33 of Set 10 | soe
# Processing Record 34 of Set 10 | dzilam gonzalez
# Processing Record 35 of Set 10 | burevestnik
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | phek
# Processing Record 38 of Set 10 | sabang
# Processing Record 39 of Set 10 | castlemaine
# Processing Record 40 of Set 10 | yueyang
# Processing Record 41 of Set 10 | jalu
# Processing Record 42 of Set 10 | porto novo
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | svetlogorsk
# Processing Record 45 of Set 10 | barranca
# Processing Record 46 of Set 10 | hasanabad
# Processing Record 47 of Set 10 | merauke
# Processing Record 48 of Set 10 | sao luis do quitunde
# Processing Record 49 of Set 10 | pitimbu
# Processing Record 0 of Set 11 | thinadhoo
# Processing Record 1 of Set 11 | kitimat
# Processing Record 2 of Set 11 | camapua
# Processing Record 3 of Set 11 | karaton
# Processing Record 4 of Set 11 | minas
# Processing Record 5 of Set 11 | ullapool
# Processing Record 6 of Set 11 | inderborskiy
# Processing Record 7 of Set 11 | manta
# Processing Record 8 of Set 11 | sivas
# Processing Record 9 of Set 11 | george town
# Processing Record 10 of Set 11 | goderich
# Processing Record 11 of Set 11 | dali
# Processing Record 12 of Set 11 | strezhevoy
# Processing Record 13 of Set 11 | mariental
# Processing Record 14 of Set 11 | boueni
# Processing Record 15 of Set 11 | mahon
# Processing Record 16 of Set 11 | abaza
# Processing Record 17 of Set 11 | uyuni
# Processing Record 18 of Set 11 | olden
# Processing Record 19 of Set 11 | hunterville
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | manokwari
# Processing Record 22 of Set 11 | tunceli
# Processing Record 23 of Set 11 | ghanzi
# Processing Record 24 of Set 11 | surgut
# Processing Record 25 of Set 11 | zhanjiang
# Processing Record 26 of Set 11 | micheweni
# Processing Record 27 of Set 11 | ballina
# Processing Record 28 of Set 11 | dunedin
# Processing Record 29 of Set 11 | reinosa
# Processing Record 30 of Set 11 | ayan
# Processing Record 31 of Set 11 | mao
# Processing Record 32 of Set 11 | lolua
# Processing Record 33 of Set 11 | otradnoye
# Processing Record 34 of Set 11 | ulladulla
# Processing Record 35 of Set 11 | jinchang
# Processing Record 36 of Set 11 | serebryansk
# Processing Record 37 of Set 11 | dolbeau
# Processing Record 38 of Set 11 | pozo colorado
# Processing Record 39 of Set 11 | lastoursville
# Processing Record 40 of Set 11 | okaihau
# Processing Record 41 of Set 11 | daloa
# Processing Record 42 of Set 11 | khonuu
# Processing Record 43 of Set 11 | olafsvik
# Processing Record 44 of Set 11 | morros
# Processing Record 45 of Set 11 | katangli
# Processing Record 46 of Set 11 | lewisporte
# Processing Record 47 of Set 11 | finschhafen
# Processing Record 48 of Set 11 | nerchinskiy zavod
# Processing Record 49 of Set 11 | gondanglegi
# Processing Record 0 of Set 12 | benjamin constant
# Processing Record 1 of Set 12 | aborlan
# Processing Record 2 of Set 12 | tiznit
# Processing Record 3 of Set 12 | aktas
# Processing Record 4 of Set 12 | sorland
# Processing Record 5 of Set 12 | haapiti
# Processing Record 6 of Set 12 | griffith
# Processing Record 7 of Set 12 | varhaug
# Processing Record 8 of Set 12 | padang
# Processing Record 9 of Set 12 | yangjiang
# Processing Record 10 of Set 12 | pisco
# Processing Record 11 of Set 12 | dzidzantun
# Processing Record 12 of Set 12 | bambanglipuro
# Processing Record 13 of Set 12 | tigil
# Processing Record 14 of Set 12 | high rock
# Processing Record 15 of Set 12 | middelburg
# Processing Record 16 of Set 12 | pochutla
# Processing Record 17 of Set 12 | banjar
# Processing Record 18 of Set 12 | nelson bay
# Processing Record 19 of Set 12 | motozintla
# Processing Record 20 of Set 12 | caluquembe
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | miramar
# Processing Record 23 of Set 12 | praia da vitoria
# Processing Record 24 of Set 12 | nong chik
# Processing Record 25 of Set 12 | pahasu
# Processing Record 26 of Set 12 | castellamonte
# Processing Record 27 of Set 12 | tabiauea
# Processing Record 28 of Set 12 | lokosovo
# Processing Record 29 of Set 12 | naryan-mar
# Processing Record 30 of Set 12 | qunduz
# Processing Record 31 of Set 12 | creel
# Processing Record 32 of Set 12 | luangwa
# Processing Record 33 of Set 12 | zyryanka
# Processing Record 34 of Set 12 | carballo
# Processing Record 35 of Set 12 | antigonish
# Processing Record 36 of Set 12 | puerto ayacucho
# Processing Record 37 of Set 12 | altamont
# Processing Record 38 of Set 12 | ugoofaaru
# Processing Record 39 of Set 12 | muisne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
city_data_pd.head()
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          vao -19.5667  18.1167     67.39        84         100        7.85
# 1  honningsvag -19.5667  18.1167     67.39        84         100        7.85
# 2    saskylakh -19.5667  18.1167     67.39        84         100        7.85
# 3   butaritari -19.5667  18.1167     67.39        84         100        7.85
# 4      tatarsk -19.5667  18.1167     67.39        84         100        7.85
#
#   Country        Date
# 0      NA  1610072765
# 1      NA  1610072765
# 2      NA  1610072765
# 3      NA  1610072765
# 4      NA  1610072765

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  540.000000  540.000000  540.000000  540.000000  540.000000   540.00000
# mean    29.457030   21.048669   42.291667   80.277778   68.333333    11.09463
# std     35.618205   81.333236   34.181649   10.777591   38.528114     6.46892
# min    -20.342800 -135.010700  -14.820000   58.000000    0.000000     3.44000
# 25%     -4.383100  -56.154900   10.400000   73.000000   40.000000     6.46000
# 50%     32.940800   18.116700   39.990000   80.000000   90.000000     8.01000
# 75%     68.219100  105.150000   75.200000   88.000000   99.000000    16.46000
# max     72.786800  128.869400   83.070000  100.000000  100.000000    26.46000
#
#                Date
# count  5.400000e+02
# mean   1.610073e+09
# std    4.931113e+01
# min    1.610073e+09
# 25%    1.610073e+09
# 50%    1.610073e+09
# 75%    1.610073e+09
# max    1.610073e+09

# %%
#  Get the indices of cities that have humidity over 100%.
dirty_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
dirty_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_data = city_data_pd.drop(dirty_data,inplace=False)
clean_data.head()
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          vao -19.5667  18.1167     67.39        84         100        7.85
# 1  honningsvag -19.5667  18.1167     67.39        84         100        7.85
# 2    saskylakh -19.5667  18.1167     67.39        84         100        7.85
# 3   butaritari -19.5667  18.1167     67.39        84         100        7.85
# 4      tatarsk -19.5667  18.1167     67.39        84         100        7.85
#
#   Country        Date
# 0      NA  1610072765
# 1      NA  1610072765
# 2      NA  1610072765
# 3      NA  1610072765
# 4      NA  1610072765

# %%
#Extract
lats = clean_data["Lat"]
max_temp = clean_data["Max Temp"]
humidity = clean_data["Humidity"]
cloudiness = clean_data["Cloudiness"]
wind_speed = clean_data["Wind Speed"]
clean_data.to_csv(output_data_file, index_label = "City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Create plot
plt.scatter(lats, max_temp, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Max Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Create plot
plt.scatter(lats, humidity, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Create plot
plt.scatter(lats, cloudiness, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-5,105)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Create plot
plt.scatter(lats,wind_speed, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,50)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
#Create northern and southern hemisphere dataframes
northern_hemisphere = clean_data[clean_data["Lat"] >= 0]
southern_hemisphere = clean_data[clean_data["Lat"] < 0]

#Define functions for linear regression and scatter plot
def linear_regression(x,y,title,text_coordinates):
    print(f"The r-squared is : {round(st.pearsonr(x,y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize = 15, color = "red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {r-value ** 2}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Max Temp"]
linear_regression(x,y,'Max Temp',(6,30))
# Out:
# The r-squared is : -0.92
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-49df9246f3c8> in <module>
#       1 x = northern_hemisphere["Lat"]
#       2 y = northern_hemisphere["Max Temp"]
# ----> 3 linear_regression(x,y,'Max Temp',(6,30))
#
# <ipython-input-36-8b4837b504ff> in linear_regression(x, y, title, text_coordinates)
#      14     plt.xlabel('Latitude')
#      15     plt.ylabel(title)
# ---> 16     print(f"The r-value is: {r-value ** 2}")
#      17     plt.show()
#
# NameError: name 'r' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Max Temp"]
linear_regression[x,y,'Max Temp',(6,30)]

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Humidity"]
linear_regression[x,y,'Humdity',(6,30)]

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Humidity"]
linear_regression[x,y,'Humidity',(6,30)]

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Cloudiness"]
linear_regression[x,y,'Cloudiness',(6,30)]

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Cloudiness"]
linear_regression[x,y,'Cloudiness',(6,30)]

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Wind Speed"]
linear_regression[x,y,'Wind Speed',(6,30)]

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Wind Speed"]
linear_regression[x,y,'Wind Speed',(6,30)]
