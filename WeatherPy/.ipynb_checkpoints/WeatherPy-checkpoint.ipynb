# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Import today's date in mm/dd/yyyy format
today = date.today()
today = today.strftime("%m/%d/%Y")

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        #city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1
    city_url = url + "&q=" + city
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | biltine
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | sabang
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | sitio novo do tocantins
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | pontianak
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | vestmannaeyjar
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | havelock
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 1 | chunskiy
# Processing Record 22 of Set 1 | penaranda
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | san pedro
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | airai
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | banff
# Processing Record 31 of Set 1 | dalvik
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | lalas
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | shedok
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | vredendal
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | flin flon
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | sao jose da coroa grande
# Processing Record 44 of Set 1 | tulsipur
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | port hedland
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | kununurra
# Processing Record 50 of Set 1 | coihaique
# Processing Record 0 of Set 2 | hermanus
# Processing Record 1 of Set 2 | kayes
# Processing Record 2 of Set 2 | indi
# Processing Record 3 of Set 2 | storforshei
# Processing Record 4 of Set 2 | nyurba
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | nador
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | whitehorse
# Processing Record 9 of Set 2 | inzhavino
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | huallanca
# Processing Record 14 of Set 2 | kastrakion
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | kilgore
# Processing Record 17 of Set 2 | mar del plata
# Processing Record 18 of Set 2 | mwense
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | sarakhs
# Processing Record 23 of Set 2 | umm lajj
# Processing Record 24 of Set 2 | vasterhaninge
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | yangjiang
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | puerto escondido
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | sur
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | nizwa
# Processing Record 34 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | ler
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 2 | ligayan
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | savannah bight
# Processing Record 42 of Set 2 | luanda
# Processing Record 43 of Set 2 | taupo
# Processing Record 44 of Set 2 | maniitsoq
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | evensk
# Processing Record 47 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | isangel
# Processing Record 0 of Set 3 | kamenka
# Processing Record 1 of Set 3 | san ignacio
# Processing Record 2 of Set 3 | ponta delgada
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | huancabamba
# Processing Record 5 of Set 3 | santa cruz del sur
# Processing Record 6 of Set 3 | sorland
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | grand gaube
# Processing Record 9 of Set 3 | henties bay
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | caravelas
# Processing Record 12 of Set 3 | morlaix
# Processing Record 13 of Set 3 | sawakin
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | ranong
# Processing Record 17 of Set 3 | chokurdakh
# Processing Record 18 of Set 3 | rio tercero
# Processing Record 19 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 3 | walvis bay
# Processing Record 21 of Set 3 | marawi
# Processing Record 22 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 3 | mus
# Processing Record 24 of Set 3 | yanam
# Processing Record 25 of Set 3 | omsukchan
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | mount gambier
# Processing Record 28 of Set 3 | salta
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | zyryanovsk
# Processing Record 31 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | goya
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | feijo
# Processing Record 36 of Set 3 | dayong
# Processing Record 37 of Set 3 | muriwai beach
# Processing Record 38 of Set 3 | tuatapere
# Processing Record 39 of Set 3 | solnechnyy
# Processing Record 40 of Set 3 | kailua
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | zhezkazgan
# Processing Record 43 of Set 3 | manggar
# Processing Record 44 of Set 3 | saint-pierre
# Processing Record 45 of Set 3 | saint-ambroise
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | owando
# Processing Record 48 of Set 3 | steinkjer
# Processing Record 49 of Set 3 | umm kaddadah
# Processing Record 0 of Set 4 | timra
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | vaini
# Processing Record 3 of Set 4 | aksu
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | kathmandu
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | tessalit
# Processing Record 10 of Set 4 | comodoro rivadavia
# Processing Record 11 of Set 4 | mogwase
# Processing Record 12 of Set 4 | aswan
# Processing Record 13 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 4 | conceicao do araguaia
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | ambulu
# Processing Record 18 of Set 4 | akyab
# Processing Record 19 of Set 4 | severo-kurilsk
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | dargaville
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | capitao poco
# Processing Record 25 of Set 4 | rodrigues alves
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | micheweni
# Processing Record 28 of Set 4 | faya
# Processing Record 29 of Set 4 | stornoway
# Processing Record 30 of Set 4 | durban
# Processing Record 31 of Set 4 | trogir
# Processing Record 32 of Set 4 | kieta
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | kaeo
# Processing Record 35 of Set 4 | broken hill
# Processing Record 36 of Set 4 | ayr
# Processing Record 37 of Set 4 | sao joao da barra
# Processing Record 38 of Set 4 | meulaboh
# Processing Record 39 of Set 4 | lahaina
# Processing Record 40 of Set 4 | lavrentiya
# Processing Record 41 of Set 4 | leningradskiy
# Processing Record 42 of Set 4 | vao
# Processing Record 43 of Set 4 | vung tau
# Processing Record 44 of Set 4 | avera
# Processing Record 45 of Set 4 | paamiut
# Processing Record 46 of Set 4 | skibbereen
# Processing Record 47 of Set 4 | castrillon
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | dolores
# Processing Record 0 of Set 5 | shasta lake
# Processing Record 1 of Set 5 | srednekolymsk
# Processing Record 2 of Set 5 | limay
# Processing Record 3 of Set 5 | haines junction
# Processing Record 4 of Set 5 | ust-koksa
# Processing Record 5 of Set 5 | hasaki
# Processing Record 6 of Set 5 | kisangani
# Processing Record 7 of Set 5 | iberia
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | alice springs
# Processing Record 11 of Set 5 | oranjemund
# Processing Record 12 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 13 of Set 5 | san carlos de bariloche
# Processing Record 14 of Set 5 | sangar
# Processing Record 15 of Set 5 | atambua
# Processing Record 16 of Set 5 | najran
# Processing Record 17 of Set 5 | russell
# Processing Record 18 of Set 5 | mayahi
# Processing Record 19 of Set 5 | papetoai
# Processing Record 20 of Set 5 | mapiripan
# Processing Record 21 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 5 | kaputa
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | bambanglipuro
# Processing Record 25 of Set 5 | sobolevo
# Processing Record 26 of Set 5 | pedernales
# Processing Record 27 of Set 5 | san vicente
# Processing Record 28 of Set 5 | mount pleasant
# Processing Record 29 of Set 5 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 30 of Set 5 | nushki
# Processing Record 31 of Set 5 | mandalgovi
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | kampong cham
# Processing Record 34 of Set 5 | mogadouro
# Processing Record 35 of Set 5 | luangwa
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | lagoa
# Processing Record 38 of Set 5 | acapulco
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | cidreira
# Processing Record 42 of Set 5 | libertad
# Processing Record 43 of Set 5 | trelew
# Processing Record 44 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 5 | tommot
# Processing Record 46 of Set 5 | codrington
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | raudeberg
# Processing Record 49 of Set 5 | siocon
# Processing Record 0 of Set 6 | wadi musa
# Processing Record 1 of Set 6 | ust-nera
# Processing Record 2 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 3 of Set 6 | ambon
# Processing Record 4 of Set 6 | shenjiamen
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | batsfjord
# Processing Record 7 of Set 6 | ygatimi
# Processing Record 8 of Set 6 | nouadhibou
# Processing Record 9 of Set 6 | galveston
# Processing Record 10 of Set 6 | bell ville
# Processing Record 11 of Set 6 | teya
# Processing Record 12 of Set 6 | atar
# Processing Record 13 of Set 6 | geraldton
# Processing Record 14 of Set 6 | poum
# Processing Record 15 of Set 6 | tazovskiy
# Processing Record 16 of Set 6 | annamalainagar
# Processing Record 17 of Set 6 | gimbi
# Processing Record 18 of Set 6 | gwadar
# Processing Record 19 of Set 6 | turbat
# Processing Record 20 of Set 6 | san cristobal
# Processing Record 21 of Set 6 | fairbanks
# Processing Record 22 of Set 6 | emba
# Processing Record 23 of Set 6 | sakaiminato
# Processing Record 24 of Set 6 | benton harbor
# Processing Record 25 of Set 6 | muisne
# Processing Record 26 of Set 6 | naples
# Processing Record 27 of Set 6 | araouane
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | rocha
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | labytnangi
# Processing Record 32 of Set 6 | fershampenuaz
# Processing Record 33 of Set 6 | manta
# Processing Record 34 of Set 6 | pacific grove
# Processing Record 35 of Set 6 | abu kamal
# Processing Record 36 of Set 6 | izumo
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | nieuw amsterdam
# Processing Record 39 of Set 6 | karratha
# Processing Record 40 of Set 6 | price
# Processing Record 41 of Set 6 | svetlyy
# Processing Record 42 of Set 6 | yulara
# Processing Record 43 of Set 6 | a coruna
# Processing Record 44 of Set 6 | warrensburg
# Processing Record 45 of Set 6 | katherine
# Processing Record 46 of Set 6 | nampa
# Processing Record 47 of Set 6 | pouembout
# Processing Record 48 of Set 6 | torbay
# Processing Record 49 of Set 6 | springbok
# Processing Record 0 of Set 7 | iralaya
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 7 | pala
# Processing Record 4 of Set 7 | new waterford
# Processing Record 5 of Set 7 | hami
# Processing Record 6 of Set 7 | rio gallegos
# Processing Record 7 of Set 7 | port lincoln
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | valdosta
# Processing Record 10 of Set 7 | kijang
# Processing Record 11 of Set 7 | povenets
# Processing Record 12 of Set 7 | calvillo
# Processing Record 13 of Set 7 | asfi
# Processing Record 14 of Set 7 | wagar
# Processing Record 15 of Set 7 | mogadishu
# Processing Record 16 of Set 7 | berlevag
# Processing Record 17 of Set 7 | cayenne
# Processing Record 18 of Set 7 | the pas
# Processing Record 19 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 20 of Set 7 | kualakapuas
# Processing Record 21 of Set 7 | mahajanga
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | bonavista
# Processing Record 24 of Set 7 | laerdalsoyri
# Processing Record 25 of Set 7 | tocopilla
# Processing Record 26 of Set 7 | dwarka
# Processing Record 27 of Set 7 | bentiu
# Processing Record 28 of Set 7 | alakurtti
# Processing Record 29 of Set 7 | los llanos de aridane
# Processing Record 30 of Set 7 | upata
# Processing Record 31 of Set 7 | miracema do tocantins
# Processing Record 32 of Set 7 | naze
# Processing Record 33 of Set 7 | thinadhoo
# Processing Record 34 of Set 7 | caraquet
# Processing Record 35 of Set 7 | teahupoo
# Processing Record 36 of Set 7 | lopatino
# Processing Record 37 of Set 7 | gimli
# Processing Record 38 of Set 7 | dharur
# Processing Record 39 of Set 7 | clarence town
# Processing Record 40 of Set 7 | aklavik
# Processing Record 41 of Set 7 | zyryanka
# Processing Record 42 of Set 7 | whittlesea
# Processing Record 43 of Set 7 | san andres
# Processing Record 44 of Set 7 | svetlogorsk
# Processing Record 45 of Set 7 | vardo
# Processing Record 46 of Set 7 | gurupi
# Processing Record 47 of Set 7 | fort nelson
# Processing Record 48 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 7 | manokwari
# Processing Record 0 of Set 8 | krasnoselkup
# Processing Record 1 of Set 8 | bilibino
# Processing Record 2 of Set 8 | imeni babushkina
# Processing Record 3 of Set 8 | nortelandia
# Processing Record 4 of Set 8 | chilca
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | natal
# Processing Record 7 of Set 8 | betioky
# Processing Record 8 of Set 8 | norsup
# Processing Record 9 of Set 8 | kegalla
# City not found. Skipping...
# Processing Record 10 of Set 8 | yoichi
# Processing Record 11 of Set 8 | nemuro
# Processing Record 12 of Set 8 | wanning
# Processing Record 13 of Set 8 | mehamn
# Processing Record 14 of Set 8 | rioja
# Processing Record 15 of Set 8 | marsabit
# Processing Record 16 of Set 8 | stuartfield
# Processing Record 17 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | ostersund
# Processing Record 20 of Set 8 | murray bridge
# Processing Record 21 of Set 8 | vaitape
# Processing Record 22 of Set 8 | jacareacanga
# Processing Record 23 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 8 | excelsior springs
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | port keats
# Processing Record 28 of Set 8 | alamosa
# Processing Record 29 of Set 8 | tuy hoa
# Processing Record 30 of Set 8 | saint-michel-des-saints
# Processing Record 31 of Set 8 | mayo
# Processing Record 32 of Set 8 | rafaela
# Processing Record 33 of Set 8 | canon city
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | muros
# Processing Record 36 of Set 8 | eyl
# Processing Record 37 of Set 8 | morondava
# Processing Record 38 of Set 8 | laguna
# Processing Record 39 of Set 8 | huaral
# Processing Record 40 of Set 8 | jinsha
# Processing Record 41 of Set 8 | pahrump
# Processing Record 42 of Set 8 | college
# Processing Record 43 of Set 8 | zharkent
# Processing Record 44 of Set 8 | udachnyy
# Processing Record 45 of Set 8 | alta floresta
# Processing Record 46 of Set 8 | marsa matruh
# Processing Record 47 of Set 8 | vostok
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | asau
# Processing Record 0 of Set 9 | bathsheba
# Processing Record 1 of Set 9 | kloulklubed
# Processing Record 2 of Set 9 | katsuura
# Processing Record 3 of Set 9 | sydney
# Processing Record 4 of Set 9 | pevek
# Processing Record 5 of Set 9 | saint andrews
# Processing Record 6 of Set 9 | broome
# Processing Record 7 of Set 9 | sao filipe
# Processing Record 8 of Set 9 | namatanai
# Processing Record 9 of Set 9 | samarai
# Processing Record 10 of Set 9 | bonoua
# Processing Record 11 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 9 | chase
# Processing Record 13 of Set 9 | sandwick
# Processing Record 14 of Set 9 | quelimane
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 9 | rio branco
# Processing Record 17 of Set 9 | bereda
# Processing Record 18 of Set 9 | graaff-reinet
# Processing Record 19 of Set 9 | lamu
# Processing Record 20 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 9 | grindavik
# Processing Record 22 of Set 9 | carballo
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 9 | safaga
# Processing Record 26 of Set 9 | talnakh
# Processing Record 27 of Set 9 | bull savanna
# Processing Record 28 of Set 9 | bertoua
# Processing Record 29 of Set 9 | gat
# Processing Record 30 of Set 9 | yatou
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 9 | lenger
# Processing Record 34 of Set 9 | sao gabriel da cachoeira
# Processing Record 35 of Set 9 | conner
# Processing Record 36 of Set 9 | sambava
# Processing Record 37 of Set 9 | sokoni
# Processing Record 38 of Set 9 | mercedes
# Processing Record 39 of Set 9 | shibetsu
# Processing Record 40 of Set 9 | kimbe
# Processing Record 41 of Set 9 | klaksvik
# Processing Record 42 of Set 9 | ulladulla
# Processing Record 43 of Set 9 | castro
# Processing Record 44 of Set 9 | port moresby
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | oum hadjer
# Processing Record 47 of Set 9 | cherskiy
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | khasan
# Processing Record 0 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 2 of Set 10 | lieksa
# Processing Record 3 of Set 10 | san quintin
# Processing Record 4 of Set 10 | rehoboth
# Processing Record 5 of Set 10 | vila
# Processing Record 6 of Set 10 | rio grande
# Processing Record 7 of Set 10 | kahului
# Processing Record 8 of Set 10 | pisco
# Processing Record 9 of Set 10 | kelso
# Processing Record 10 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 10 | peace river
# Processing Record 12 of Set 10 | aquiraz
# Processing Record 13 of Set 10 | linares
# Processing Record 14 of Set 10 | lamin
# Processing Record 15 of Set 10 | yenagoa
# Processing Record 16 of Set 10 | rosehearty
# Processing Record 17 of Set 10 | rabo de peixe
# Processing Record 18 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 10 | kropotkin
# Processing Record 20 of Set 10 | pangody
# Processing Record 21 of Set 10 | puro
# Processing Record 22 of Set 10 | tual
# Processing Record 23 of Set 10 | kamina
# Processing Record 24 of Set 10 | agadez
# Processing Record 25 of Set 10 | dospat
# Processing Record 26 of Set 10 | namibe
# Processing Record 27 of Set 10 | odda
# Processing Record 28 of Set 10 | colorado
# Processing Record 29 of Set 10 | urcos
# Processing Record 30 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 31 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 10 | yerbogachen
# Processing Record 33 of Set 10 | anadyr
# Processing Record 34 of Set 10 | saint george
# Processing Record 35 of Set 10 | northampton
# Processing Record 36 of Set 10 | quzhou
# Processing Record 37 of Set 10 | bagdarin
# Processing Record 38 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | alindao
# Processing Record 40 of Set 10 | ushtobe
# Processing Record 41 of Set 10 | sibolga
# Processing Record 42 of Set 10 | virginia beach
# Processing Record 43 of Set 10 | yarmouth
# Processing Record 44 of Set 10 | richards bay
# Processing Record 45 of Set 10 | kajaani
# Processing Record 46 of Set 10 | saint-georges
# Processing Record 47 of Set 10 | buala
# Processing Record 48 of Set 10 | hearst
# Processing Record 49 of Set 10 | ilhabela
# Processing Record 0 of Set 11 | magistralnyy
# Processing Record 1 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 2 of Set 11 | bida
# Processing Record 3 of Set 11 | cabedelo
# Processing Record 4 of Set 11 | andenes
# Processing Record 5 of Set 11 | khakhea
# Processing Record 6 of Set 11 | semey
# Processing Record 7 of Set 11 | navapur
# City not found. Skipping...
# Processing Record 8 of Set 11 | truro
# Processing Record 9 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 10 of Set 11 | sungaipenuh
# Processing Record 11 of Set 11 | wucheng
# Processing Record 12 of Set 11 | olafsvik
# Processing Record 13 of Set 11 | murchison
# Processing Record 14 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 15 of Set 11 | moree
# Processing Record 16 of Set 11 | tiznit
# Processing Record 17 of Set 11 | jalingo
# Processing Record 18 of Set 11 | hovd
# Processing Record 19 of Set 11 | kalaleh
# Processing Record 20 of Set 11 | imbituba
# Processing Record 21 of Set 11 | goure
# Processing Record 22 of Set 11 | aleksandrov gay
# Processing Record 23 of Set 11 | benghazi
# Processing Record 24 of Set 11 | ca mau
# Processing Record 25 of Set 11 | durant
# Processing Record 26 of Set 11 | dauphin
# Processing Record 27 of Set 11 | caraz
# Processing Record 28 of Set 11 | lucapa
# Processing Record 29 of Set 11 | lasa
# Processing Record 30 of Set 11 | yasothon
# Processing Record 31 of Set 11 | king city
# Processing Record 32 of Set 11 | abnub
# Processing Record 33 of Set 11 | sayyan
# Processing Record 34 of Set 11 | belmonte
# Processing Record 35 of Set 11 | norman wells
# Processing Record 36 of Set 11 | taunggyi
# Processing Record 37 of Set 11 | guna
# Processing Record 38 of Set 11 | okha
# Processing Record 39 of Set 11 | lompoc
# Processing Record 40 of Set 11 | shelburne
# Processing Record 41 of Set 11 | chuy
# Processing Record 42 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 11 | lata
# Processing Record 44 of Set 11 | ust-tsilma
# Processing Record 45 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 11 | jalu
# Processing Record 48 of Set 11 | senanga
# Processing Record 49 of Set 11 | lorengau
# Processing Record 0 of Set 12 | merrill
# Processing Record 1 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 12 | coro
# Processing Record 3 of Set 12 | durango
# Processing Record 4 of Set 12 | puerto colombia
# Processing Record 5 of Set 12 | vanavara
# Processing Record 6 of Set 12 | mitu
# Processing Record 7 of Set 12 | kasempa
# Processing Record 8 of Set 12 | badou
# Processing Record 9 of Set 12 | ambatofinandrahana
# Processing Record 10 of Set 12 | mahibadhoo
# Processing Record 11 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 12 | mocuba
# Processing Record 13 of Set 12 | san rafael
# Processing Record 14 of Set 12 | wahpeton
# Processing Record 15 of Set 12 | labuhan
# Processing Record 16 of Set 12 | camabatela
# Processing Record 17 of Set 12 | makat
# Processing Record 18 of Set 12 | basco
# Processing Record 19 of Set 12 | middelburg
# Processing Record 20 of Set 12 | aitape
# Processing Record 21 of Set 12 | ngunguru
# Processing Record 22 of Set 12 | changli
# Processing Record 23 of Set 12 | tezu
# Processing Record 24 of Set 12 | port hardy
# Processing Record 25 of Set 12 | cassilandia
# Processing Record 26 of Set 12 | baherden
# Processing Record 27 of Set 12 | kushmurun
# Processing Record 28 of Set 12 | monitos
# Processing Record 29 of Set 12 | konevo
# Processing Record 30 of Set 12 | teontepec
# Processing Record 31 of Set 12 | seoul
# Processing Record 32 of Set 12 | kiunga
# Processing Record 33 of Set 12 | seredka
# Processing Record 34 of Set 12 | acari
# Processing Record 35 of Set 12 | harper
# Processing Record 36 of Set 12 | sinnamary
# Processing Record 37 of Set 12 | kakching
# Processing Record 38 of Set 12 | kendari
# Processing Record 39 of Set 12 | ormara
# Processing Record 40 of Set 12 | champasak
# Processing Record 41 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 42 of Set 12 | beidao
# Processing Record 43 of Set 12 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 44 of Set 12 | san carlos
# Processing Record 45 of Set 12 | havre-saint-pierre
# Processing Record 46 of Set 12 | colomi
# Processing Record 47 of Set 12 | kumba
# Processing Record 48 of Set 12 | amahai
# Processing Record 49 of Set 12 | inhambane
# Processing Record 0 of Set 13 | vilyuysk
# Processing Record 1 of Set 13 | mount darwin
# Processing Record 2 of Set 13 | krabi
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 5 of Set 13 | seydi
# Processing Record 6 of Set 13 | banjar
# Processing Record 7 of Set 13 | blairmore
# Processing Record 8 of Set 13 | urusha
# Processing Record 9 of Set 13 | goundam
# Processing Record 10 of Set 13 | barberton
# Processing Record 11 of Set 13 | cururupu
# Processing Record 12 of Set 13 | wad madani
# Processing Record 13 of Set 13 | shar
# Processing Record 14 of Set 13 | tura
# Processing Record 15 of Set 13 | juneau
# Processing Record 16 of Set 13 | chapais
# Processing Record 17 of Set 13 | bundaberg
# Processing Record 18 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 13 | senador jose porfirio
# Processing Record 20 of Set 13 | high rock
# Processing Record 21 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 22 of Set 13 | sabzevar
# Processing Record 23 of Set 13 | manicore
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
city_data_pd.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       busselton -33.6500  115.3333     64.00        65          68
# 1       cape town -33.9258   18.4232     70.00        68           0
# 2         biltine  14.5333   20.9167     66.60        24           0
# 3          atuona  -9.8000 -139.0333     77.59        80           3
# 4  saint-philippe -21.3585   55.7679     77.00        88          40
#
#    Wind Speed Country        Date
# 0        1.99      AU  1610409372
# 1       13.80      ZA  1610409119
# 2       14.14      TD  1610409372
# 3       15.75      PF  1610409372
# 4        2.30      RE  1610409372

# %%
#Extract
lats = city_data_pd["Lat"]
max_temp =city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]
city_data_pd.to_csv(output_data_file, index_label = "City_ID")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  567.000000  567.000000  567.000000  567.000000  567.000000  567.000000
# mean    17.556702   16.385210   50.886808   74.590829   54.765432    7.911869
# std     33.729599   90.600326   30.724222   18.663331   38.471774    5.944965
# min    -54.800000 -175.200000  -43.100000   15.000000    0.000000    0.040000
# 25%     -9.837800  -65.358400   30.200000   65.000000   14.000000    3.400000
# 50%     18.800300   20.916700   63.300000   79.000000   73.000000    6.170000
# 75%     45.954650   97.834050   75.830000   88.000000   90.000000   11.170000
# max     78.218600  178.416700   91.400000  100.000000  100.000000   35.680000
#
#                Date
# count  5.670000e+02
# mean   1.610409e+09
# std    6.743832e+01
# min    1.610409e+09
# 25%    1.610409e+09
# 50%    1.610409e+09
# 75%    1.610409e+09
# max    1.610409e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Create plot
plt.scatter(lats, max_temp, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Max Temp.png")
plt.show()

# %% [markdown]
# City Latitude vs. Max Temperature plot shows the maximum temperature recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Create plot
plt.scatter(lats, humidity, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Humidity.png")

# %% [markdown]
# City Latitude vs. Humidity plot shows the humidity percentage recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Create plot
plt.scatter(lats, cloudiness, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-5,105)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Cloudiness.png")

# %% [markdown]
# City Latitude vs. Cloudiness plot shows the cloudiness percentage recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Create plot
plt.scatter(lats,wind_speed, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,50)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Wind Speed.png")

# %% [markdown]
# City Latitude vs. Wind Speed plot shows the wind speed recorded in miles per hour at the latitude of the city it was taken from.

# %% [markdown]
# ## Linear Regression

# %%
#Create northern and southern hemisphere dataframes
northern_hemisphere = city_data_pd[city_data_pd["Lat"] >= 0]
southern_hemisphere = city_data_pd[city_data_pd["Lat"] < 0]

#Define functions for linear regression and scatter plot
def linear_regression(x,y,title,text_coordinates):
    print(f"The r-squared is : {round(st.pearsonr(x,y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept,2))
    plt.scatter(x,y, alpha=0.5, edgecolor='black')
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize = 15, color = "red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue ** 2}")
    print(f"The line equation is: {line_eq}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Max Temp"]
plt.title(f'Northern Hemisphere: City Latitude vs. Max Temp ({today})')
linear_regression(x,y,'Max Temp (F)',(0,-40))

plt.savefig("output_data/Northern_MaxTempVsLat_Regression.png")
# Out:
# The r-squared is : -0.86
# The r-value is: 0.733234260220519
# The line equation is: y = -1.29x = 87.95

# %% [markdown]
# There is a strong negative correlation of higher temperatures at latitudes closer to the equator and cooler temperatures as you increase north.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Max Temp"]
plt.title(f'Southern Hemisphere: City Latitude vs. Max Temp ({today})')
linear_regression(x,y,'Max Temp (F)',(-30,50))
plt.savefig("output_data/Southern_MaxTemp_Regression.png")
# Out:
# The r-squared is : 0.47
# The r-value is: 0.22221392953507121
# The line equation is: y = 0.31x = 80.7

# %% [markdown]
# There is a moderate positive correlation of the temperature decreasing the farther south from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Humidity"]
plt.title(f'Northern Hemisphere: City Latitude vs. Humidity ({today})')
linear_regression(x,y,'Humdity (%)',(40,20))
plt.savefig("output_data/Northern_Humidity_Regression.png")
# Out:
# The r-squared is : 0.4
# The r-value is: 0.15630981590957707
# The line equation is: y = 0.37x = 60.61

# %% [markdown]
# There is a weak positive correlation as humidity increases the farther north you go.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Humidity"]
plt.title(f'Southern Hemisphere: City Latitude vs. Humidity ({today})')
linear_regression(x,y,'Humidity (%)',(-25,20))
plt.savefig("output_data/Southern_Humidity_Regression.png")
# Out:
# The r-squared is : 0.49
# The r-value is: 0.24102066263563182
# The line equation is: y = 0.64x = 87.65

# %% [markdown]
# There is a very weak positive correlation between humidity and the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Cloudiness"]
plt.title(f'Northern Hemisphere: City Latitude vs. Cloudiness ({today})')
linear_regression(x,y,'Cloudiness (%)',(40,10))
plt.savefig("output_data/Northern_Cloudiness_Regression.png")
# Out:
# The r-squared is : 0.23
# The r-value is: 0.051800671701810824
# The line equation is: y = 0.44x = 37.26

# %% [markdown]
# There is a positive correlation shown in the plot, however the plot also shows cloudiness at all percentages in most of the latitudes.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Cloudiness"]
plt.title(f'Southern Hemisphere: City Latitude vs. Cloudiness ({today})')
linear_regression(x,y,'Cloudiness (%)',(-55,22))
plt.savefig("output_data/Southern_Cloudiness_Regression.png")
# Out:
# The r-squared is : 0.24
# The r-value is: 0.05792237382210257
# The line equation is: y = 0.66x = 70.38

# %% [markdown]
# There is a positive correlation shown again, however the graph shows again most cloudiness percentages at most of the latitudes. This is also confirmed with the northern hemisphere and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Wind Speed"]
plt.title(f'Northern Hemisphere: City Latitude vs. Wind Speed ({today})')
linear_regression(x,y,'Wind Speed (mph)',(10,30))
plt.savefig("output_data/Northern_WindSpeed_Regression.png")
# Out:
# The r-squared is : -0.0
# The r-value is: 1.5241360751107443e-06
# The line equation is: y = -0.0x = 8.1

# %% [markdown]
# There is a very weak correlation between moving north and wind speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Wind Speed"]
plt.title(f'Southern Hemisphere: City Latitude vs. Wind Speed ({today})')
linear_regression(x,y,'Wind Speed (mph)',(-55,22))
plt.savefig("output_data/Southern_WindSpeed_Regression.png")
# Out:
# The r-squared is : -0.25
# The r-value is: 0.06282837306505365
# The line equation is: y = -0.11x = 5.3

# %% [markdown]
# There is a negative correlation between moving farther south from the equator and wind speed.
