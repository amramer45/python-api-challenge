# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Import today's date in mm/dd/yyyy format
today = date.today()
today = today.strftime("%m/%d/%Y")

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        #city_url = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1
    city_url = url + "&q=" + city
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | sinnamary
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | gurlan
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | alofi
# Processing Record 11 of Set 1 | ballina
# Processing Record 12 of Set 1 | russell
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | popondetta
# Processing Record 15 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 1 | morondava
# Processing Record 17 of Set 1 | lompoc
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | poya
# Processing Record 20 of Set 1 | palembang
# Processing Record 21 of Set 1 | banyo
# Processing Record 22 of Set 1 | san angelo
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | suicheng
# Processing Record 26 of Set 1 | bilma
# Processing Record 27 of Set 1 | komsomolskiy
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | general pico
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | teya
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | asau
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | tarakan
# Processing Record 40 of Set 1 | alice springs
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | sijunjung
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | constitucion
# Processing Record 46 of Set 1 | brae
# Processing Record 47 of Set 1 | nargana
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | voh
# Processing Record 1 of Set 2 | kirakira
# Processing Record 2 of Set 2 | coffs harbour
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | champerico
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | maningrida
# Processing Record 9 of Set 2 | sola
# Processing Record 10 of Set 2 | buyukcavuslu
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | kaeo
# Processing Record 16 of Set 2 | la ronge
# Processing Record 17 of Set 2 | sidi ali
# Processing Record 18 of Set 2 | batagay
# Processing Record 19 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 20 of Set 2 | maralal
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | atsiki
# City not found. Skipping...
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | abu kamal
# Processing Record 29 of Set 2 | bedford
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | imbituba
# Processing Record 32 of Set 2 | atbasar
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | ravar
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | san buenaventura
# Processing Record 37 of Set 2 | bohuslav
# Processing Record 38 of Set 2 | naze
# Processing Record 39 of Set 2 | henties bay
# Processing Record 40 of Set 2 | mudgee
# Processing Record 41 of Set 2 | lasa
# Processing Record 42 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | owando
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | dinhata
# Processing Record 49 of Set 2 | mayumba
# Processing Record 0 of Set 3 | coihaique
# Processing Record 1 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | mathbaria
# Processing Record 4 of Set 3 | boromo
# Processing Record 5 of Set 3 | atasu
# Processing Record 6 of Set 3 | sestri levante
# Processing Record 7 of Set 3 | lhokseumawe
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | mao
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | san patricio
# Processing Record 12 of Set 3 | rio gallegos
# Processing Record 13 of Set 3 | kenai
# Processing Record 14 of Set 3 | chulym
# Processing Record 15 of Set 3 | mayo
# Processing Record 16 of Set 3 | araouane
# Processing Record 17 of Set 3 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 18 of Set 3 | yumen
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | san cristobal
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | kieta
# Processing Record 25 of Set 3 | sovetsk
# Processing Record 26 of Set 3 | jimenez
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | smithers
# Processing Record 30 of Set 3 | tezu
# Processing Record 31 of Set 3 | archidona
# Processing Record 32 of Set 3 | saquarema
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | moose factory
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | pokrovsk
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | beloha
# Processing Record 39 of Set 3 | puerto ayacucho
# Processing Record 40 of Set 3 | tazovskiy
# Processing Record 41 of Set 3 | mbandaka
# Processing Record 42 of Set 3 | bakchar
# Processing Record 43 of Set 3 | redwater
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | saint-pierre
# Processing Record 46 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 3 | talakan
# Processing Record 49 of Set 3 | svobodnyy
# Processing Record 0 of Set 4 | hilo
# Processing Record 1 of Set 4 | beroroha
# Processing Record 2 of Set 4 | tashtyp
# Processing Record 3 of Set 4 | okhotsk
# Processing Record 4 of Set 4 | butembo
# Processing Record 5 of Set 4 | kulim
# Processing Record 6 of Set 4 | naron
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | qaanaaq
# Processing Record 9 of Set 4 | jieshi
# Processing Record 10 of Set 4 | ucluelet
# Processing Record 11 of Set 4 | gizo
# Processing Record 12 of Set 4 | sambava
# Processing Record 13 of Set 4 | kaseda
# Processing Record 14 of Set 4 | pisco
# Processing Record 15 of Set 4 | presidente medici
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | fairbanks
# Processing Record 18 of Set 4 | havelock
# Processing Record 19 of Set 4 | punganuru
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | deer lake
# Processing Record 22 of Set 4 | shimoda
# Processing Record 23 of Set 4 | anuchino
# Processing Record 24 of Set 4 | abu dhabi
# Processing Record 25 of Set 4 | santa ana
# Processing Record 26 of Set 4 | erzin
# Processing Record 27 of Set 4 | klaksvik
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | mwingi
# Processing Record 30 of Set 4 | amazar
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | te anau
# Processing Record 33 of Set 4 | sorong
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | havre-saint-pierre
# Processing Record 37 of Set 4 | amapa
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | ivangorod
# Processing Record 40 of Set 4 | neiafu
# Processing Record 41 of Set 4 | ambilobe
# Processing Record 42 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | manokwari
# Processing Record 48 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 49 of Set 4 | pakaur
# Processing Record 0 of Set 5 | yaizu
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | anadyr
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | kilindoni
# Processing Record 6 of Set 5 | matara
# Processing Record 7 of Set 5 | pochutla
# Processing Record 8 of Set 5 | mbalmayo
# Processing Record 9 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 5 | daryapur
# Processing Record 11 of Set 5 | acapulco
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | antofagasta
# Processing Record 14 of Set 5 | avera
# Processing Record 15 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | garden city
# Processing Record 18 of Set 5 | northam
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | nago
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | baft
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | camacha
# Processing Record 26 of Set 5 | juazeiro
# Processing Record 27 of Set 5 | high level
# Processing Record 28 of Set 5 | atar
# Processing Record 29 of Set 5 | beamsville
# Processing Record 30 of Set 5 | port alfred
# Processing Record 31 of Set 5 | merauke
# Processing Record 32 of Set 5 | algeciras
# Processing Record 33 of Set 5 | mpanda
# Processing Record 34 of Set 5 | udachnyy
# Processing Record 35 of Set 5 | mazamari
# Processing Record 36 of Set 5 | qasigiannguit
# Processing Record 37 of Set 5 | campbell river
# Processing Record 38 of Set 5 | kungurtug
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | bealanana
# Processing Record 43 of Set 5 | heinola
# Processing Record 44 of Set 5 | oistins
# Processing Record 45 of Set 5 | tasiilaq
# Processing Record 46 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 5 | sisimiut
# Processing Record 48 of Set 5 | pokosnoye
# Processing Record 49 of Set 5 | qeshm
# Processing Record 0 of Set 6 | gat
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | rockhampton
# Processing Record 3 of Set 6 | vila
# Processing Record 4 of Set 6 | mogadishu
# Processing Record 5 of Set 6 | gunjur
# Processing Record 6 of Set 6 | trairi
# Processing Record 7 of Set 6 | egvekinot
# Processing Record 8 of Set 6 | bucerias
# Processing Record 9 of Set 6 | butaritari
# Processing Record 10 of Set 6 | lagoa
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | shambu
# Processing Record 14 of Set 6 | broken hill
# Processing Record 15 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | tilichiki
# Processing Record 18 of Set 6 | isangel
# Processing Record 19 of Set 6 | nova borova
# Processing Record 20 of Set 6 | inga
# Processing Record 21 of Set 6 | bandarbeyla
# Processing Record 22 of Set 6 | jumla
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | montanhas
# Processing Record 25 of Set 6 | ormond beach
# Processing Record 26 of Set 6 | malanville
# Processing Record 27 of Set 6 | puerto castilla
# Processing Record 28 of Set 6 | kabo
# Processing Record 29 of Set 6 | salina
# Processing Record 30 of Set 6 | tevaitoa
# Processing Record 31 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | nanortalik
# Processing Record 36 of Set 6 | bacolod
# Processing Record 37 of Set 6 | wisconsin rapids
# Processing Record 38 of Set 6 | matadi
# Processing Record 39 of Set 6 | dandong
# Processing Record 40 of Set 6 | ponta do sol
# Processing Record 41 of Set 6 | aracuai
# Processing Record 42 of Set 6 | svetlogorsk
# Processing Record 43 of Set 6 | koslan
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | tecoanapa
# Processing Record 46 of Set 6 | bowen
# Processing Record 47 of Set 6 | esperance
# Processing Record 48 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 6 | eagle pass
# Processing Record 0 of Set 7 | oyotun
# Processing Record 1 of Set 7 | yerbogachen
# Processing Record 2 of Set 7 | zaysan
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | erenhot
# Processing Record 5 of Set 7 | norman wells
# Processing Record 6 of Set 7 | kibala
# Processing Record 7 of Set 7 | hasaki
# Processing Record 8 of Set 7 | castiglion fiorentino
# Processing Record 9 of Set 7 | ereymentau
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 7 | mariental
# Processing Record 13 of Set 7 | pangnirtung
# Processing Record 14 of Set 7 | sao filipe
# Processing Record 15 of Set 7 | korla
# Processing Record 16 of Set 7 | kiama
# Processing Record 17 of Set 7 | castro
# Processing Record 18 of Set 7 | scarborough
# Processing Record 19 of Set 7 | quang ngai
# Processing Record 20 of Set 7 | port hardy
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | tricase
# Processing Record 23 of Set 7 | zyryanka
# Processing Record 24 of Set 7 | helena
# Processing Record 25 of Set 7 | nikolskoye
# Processing Record 26 of Set 7 | adrar
# Processing Record 27 of Set 7 | tessalit
# Processing Record 28 of Set 7 | oshawa
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | porto novo
# Processing Record 31 of Set 7 | ukiah
# Processing Record 32 of Set 7 | seoul
# Processing Record 33 of Set 7 | kamenka
# Processing Record 34 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 7 | stromness
# Processing Record 36 of Set 7 | maksatikha
# Processing Record 37 of Set 7 | svetlyy
# Processing Record 38 of Set 7 | nicolas bravo
# Processing Record 39 of Set 7 | boyolangu
# Processing Record 40 of Set 7 | cuamba
# Processing Record 41 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 7 | cheremisinovo
# Processing Record 43 of Set 7 | bowmore
# Processing Record 44 of Set 7 | barrow
# Processing Record 45 of Set 7 | makat
# Processing Record 46 of Set 7 | sanchor
# Processing Record 47 of Set 7 | changli
# Processing Record 48 of Set 7 | akdepe
# Processing Record 49 of Set 7 | oda
# Processing Record 0 of Set 8 | makakilo city
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 3 of Set 8 | evensk
# Processing Record 4 of Set 8 | haines junction
# Processing Record 5 of Set 8 | basar
# Processing Record 6 of Set 8 | junagarh
# Processing Record 7 of Set 8 | katherine
# Processing Record 8 of Set 8 | ruwi
# Processing Record 9 of Set 8 | conde
# Processing Record 10 of Set 8 | saldanha
# Processing Record 11 of Set 8 | ishigaki
# Processing Record 12 of Set 8 | grand gaube
# Processing Record 13 of Set 8 | mountain home
# Processing Record 14 of Set 8 | finschhafen
# Processing Record 15 of Set 8 | keokuk
# Processing Record 16 of Set 8 | kodiak
# Processing Record 17 of Set 8 | pachino
# Processing Record 18 of Set 8 | savannakhet
# Processing Record 19 of Set 8 | okato
# Processing Record 20 of Set 8 | norsup
# Processing Record 21 of Set 8 | sept-iles
# Processing Record 22 of Set 8 | ipameri
# Processing Record 23 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 8 | belyy yar
# Processing Record 25 of Set 8 | homer
# Processing Record 26 of Set 8 | walvis bay
# Processing Record 27 of Set 8 | upernavik
# Processing Record 28 of Set 8 | san felipe
# Processing Record 29 of Set 8 | vostok
# Processing Record 30 of Set 8 | baihar
# Processing Record 31 of Set 8 | cabo san lucas
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | jackson
# Processing Record 34 of Set 8 | talikota
# Processing Record 35 of Set 8 | dryden
# Processing Record 36 of Set 8 | boende
# Processing Record 37 of Set 8 | natchez
# Processing Record 38 of Set 8 | lamar
# Processing Record 39 of Set 8 | san quintin
# Processing Record 40 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 41 of Set 8 | chara
# Processing Record 42 of Set 8 | gwadar
# Processing Record 43 of Set 8 | burica
# City not found. Skipping...
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | kyra
# Processing Record 46 of Set 8 | dinguiraye
# Processing Record 47 of Set 8 | ascension
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | mount isa
# Processing Record 0 of Set 9 | najran
# Processing Record 1 of Set 9 | poum
# Processing Record 2 of Set 9 | santiago del estero
# Processing Record 3 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 9 | sur
# Processing Record 5 of Set 9 | ekhabi
# Processing Record 6 of Set 9 | anamur
# Processing Record 7 of Set 9 | maneadero
# Processing Record 8 of Set 9 | bridlington
# Processing Record 9 of Set 9 | hami
# Processing Record 10 of Set 9 | taoudenni
# Processing Record 11 of Set 9 | challapalle
# Processing Record 12 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 9 | shubarshi
# Processing Record 14 of Set 9 | tombouctou
# Processing Record 15 of Set 9 | cerqueira cesar
# Processing Record 16 of Set 9 | berlevag
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | tomari
# Processing Record 19 of Set 9 | hambantota
# Processing Record 20 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | pandan
# Processing Record 22 of Set 9 | andenes
# Processing Record 23 of Set 9 | ancud
# Processing Record 24 of Set 9 | khuzhir
# Processing Record 25 of Set 9 | rafaela
# Processing Record 26 of Set 9 | shenkursk
# Processing Record 27 of Set 9 | devonport
# Processing Record 28 of Set 9 | san pedro
# Processing Record 29 of Set 9 | kuala kangsar
# Processing Record 30 of Set 9 | am timan
# Processing Record 31 of Set 9 | tafresh
# Processing Record 32 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | douglas
# Processing Record 34 of Set 9 | beaverlodge
# Processing Record 35 of Set 9 | honningsvag
# Processing Record 36 of Set 9 | tarko-sale
# Processing Record 37 of Set 9 | lipari
# Processing Record 38 of Set 9 | crawfordsville
# Processing Record 39 of Set 9 | aporawan
# City not found. Skipping...
# Processing Record 40 of Set 9 | kasongo-lunda
# Processing Record 41 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 9 | aqtobe
# Processing Record 43 of Set 9 | mombetsu
# Processing Record 44 of Set 9 | koumac
# Processing Record 45 of Set 9 | toba
# Processing Record 46 of Set 9 | arraial do cabo
# Processing Record 47 of Set 9 | galt
# Processing Record 48 of Set 9 | hervey bay
# Processing Record 49 of Set 9 | ahome
# Processing Record 0 of Set 10 | orikum
# Processing Record 1 of Set 10 | miles city
# Processing Record 2 of Set 10 | horizontina
# Processing Record 3 of Set 10 | port shepstone
# Processing Record 4 of Set 10 | santa marta
# Processing Record 5 of Set 10 | fukue
# Processing Record 6 of Set 10 | basco
# Processing Record 7 of Set 10 | axim
# Processing Record 8 of Set 10 | emba
# Processing Record 9 of Set 10 | ostrovnoy
# Processing Record 10 of Set 10 | laguna
# Processing Record 11 of Set 10 | irati
# Processing Record 12 of Set 10 | ambon
# Processing Record 13 of Set 10 | bereda
# Processing Record 14 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 10 | remanso
# Processing Record 16 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 10 | novyy urengoy
# Processing Record 18 of Set 10 | kavaratti
# Processing Record 19 of Set 10 | lewiston
# Processing Record 20 of Set 10 | comodoro rivadavia
# Processing Record 21 of Set 10 | bourg-en-bresse
# Processing Record 22 of Set 10 | bahia blanca
# Processing Record 23 of Set 10 | margate
# Processing Record 24 of Set 10 | tura
# Processing Record 25 of Set 10 | kodinsk
# Processing Record 26 of Set 10 | tautira
# Processing Record 27 of Set 10 | buala
# Processing Record 28 of Set 10 | rapid valley
# Processing Record 29 of Set 10 | salinopolis
# Processing Record 30 of Set 10 | namibe
# Processing Record 31 of Set 10 | santa cruz
# Processing Record 32 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 35 of Set 10 | machiques
# Processing Record 36 of Set 10 | soyo
# Processing Record 37 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 38 of Set 10 | nioro
# Processing Record 39 of Set 10 | mollendo
# Processing Record 40 of Set 10 | mehamn
# Processing Record 41 of Set 10 | salalah
# Processing Record 42 of Set 10 | roebourne
# Processing Record 43 of Set 10 | karasjok
# Processing Record 44 of Set 10 | katangli
# Processing Record 45 of Set 10 | pacifica
# Processing Record 46 of Set 10 | shache
# Processing Record 47 of Set 10 | gari
# Processing Record 48 of Set 10 | douentza
# Processing Record 49 of Set 10 | takoradi
# Processing Record 0 of Set 11 | doha
# Processing Record 1 of Set 11 | svetlaya
# Processing Record 2 of Set 11 | leningradskiy
# Processing Record 3 of Set 11 | maniitsoq
# Processing Record 4 of Set 11 | solnechnyy
# Processing Record 5 of Set 11 | saint-leu
# Processing Record 6 of Set 11 | chapais
# Processing Record 7 of Set 11 | necochea
# Processing Record 8 of Set 11 | maarianhamina
# Processing Record 9 of Set 11 | ulaangom
# Processing Record 10 of Set 11 | sao paulo de olivenca
# Processing Record 11 of Set 11 | lakatoro
# Processing Record 12 of Set 11 | orizona
# Processing Record 13 of Set 11 | kyshtovka
# Processing Record 14 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 11 | bonavista
# Processing Record 17 of Set 11 | hailar
# Processing Record 18 of Set 11 | labuhan
# Processing Record 19 of Set 11 | kingsville
# Processing Record 20 of Set 11 | port blair
# Processing Record 21 of Set 11 | bolu
# Processing Record 22 of Set 11 | boyle
# Processing Record 23 of Set 11 | caravelas
# Processing Record 24 of Set 11 | port lincoln
# Processing Record 25 of Set 11 | ovalle
# Processing Record 26 of Set 11 | ust-uda
# Processing Record 27 of Set 11 | ha giang
# Processing Record 28 of Set 11 | cedral
# Processing Record 29 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | yar-sale
# Processing Record 32 of Set 11 | malaia
# Processing Record 33 of Set 11 | manzhouli
# Processing Record 34 of Set 11 | ostroleka
# Processing Record 35 of Set 11 | maragogi
# Processing Record 36 of Set 11 | dickinson
# Processing Record 37 of Set 11 | matamoros
# Processing Record 38 of Set 11 | las lomas
# Processing Record 39 of Set 11 | porto nacional
# Processing Record 40 of Set 11 | nuuk
# Processing Record 41 of Set 11 | kuytun
# Processing Record 42 of Set 11 | painesville
# Processing Record 43 of Set 11 | andrelandia
# Processing Record 44 of Set 11 | serrana
# Processing Record 45 of Set 11 | hsinchu
# Processing Record 46 of Set 11 | kudahuvadhoo
# Processing Record 47 of Set 11 | ballarat
# Processing Record 48 of Set 11 | alcains
# Processing Record 49 of Set 11 | half moon bay
# Processing Record 0 of Set 12 | paratinga
# Processing Record 1 of Set 12 | lethem
# Processing Record 2 of Set 12 | saint-tite
# Processing Record 3 of Set 12 | vao
# Processing Record 4 of Set 12 | maceio
# Processing Record 5 of Set 12 | kulhudhuffushi
# Processing Record 6 of Set 12 | lakes entrance
# Processing Record 7 of Set 12 | englewood
# Processing Record 8 of Set 12 | butajira
# Processing Record 9 of Set 12 | dharchula
# Processing Record 10 of Set 12 | methoni
# Processing Record 11 of Set 12 | micomeseng
# Processing Record 12 of Set 12 | uyemskiy
# Processing Record 13 of Set 12 | talnakh
# Processing Record 14 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 15 of Set 12 | huarmey
# Processing Record 16 of Set 12 | lokosovo
# Processing Record 17 of Set 12 | vaitape
# Processing Record 18 of Set 12 | aguimes
# Processing Record 19 of Set 12 | chulman
# Processing Record 20 of Set 12 | linjiang
# Processing Record 21 of Set 12 | nantucket
# Processing Record 22 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 12 | alpena
# Processing Record 24 of Set 12 | puerto carreno
# Processing Record 25 of Set 12 | teknaf
# Processing Record 26 of Set 12 | sabang
# Processing Record 27 of Set 12 | ponta delgada
# Processing Record 28 of Set 12 | manaus
# Processing Record 29 of Set 12 | orumiyeh
# Processing Record 30 of Set 12 | vanavara
# Processing Record 31 of Set 12 | hajnowka
# Processing Record 32 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 33 of Set 12 | usinsk
# Processing Record 34 of Set 12 | punto fijo
# Processing Record 35 of Set 12 | deputatskiy
# Processing Record 36 of Set 12 | mackay
# Processing Record 37 of Set 12 | dergaon
# Processing Record 38 of Set 12 | guerrero negro
# Processing Record 39 of Set 12 | ji-parana
# City not found. Skipping...
# Processing Record 40 of Set 12 | bull savanna
# Processing Record 41 of Set 12 | marienburg
# Processing Record 42 of Set 12 | beringovskiy
# Processing Record 43 of Set 12 | cayenne
# Processing Record 44 of Set 12 | raton
# Processing Record 45 of Set 12 | sidrolandia
# Processing Record 46 of Set 12 | gananoque
# Processing Record 47 of Set 12 | beyneu
# Processing Record 48 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 12 | zlatoustovsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          542
# Lat           542
# Lng           542
# Max Temp      542
# Humidity      542
# Cloudiness    542
# Wind Speed    542
# Country       542
# Date          542
# dtype: int64

# %%
city_data_pd.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          atuona  -9.8000 -139.0333     77.49        81           5
# 1  ribeira grande  38.5167  -28.7000     62.53        89         100
# 2         rikitea -23.1203 -134.9692     78.40        77          95
# 3      vila velha -20.3297  -40.2925     79.00        83          75
# 4       sinnamary   5.3833  -52.9500     77.68        85          43
#
#    Wind Speed Country        Date
# 0       15.77      PF  1610408207
# 1       20.11      PT  1610408207
# 2       18.39      PF  1610408208
# 3       10.36      BR  1610408208
# 4       12.62      GF  1610408208

# %%
#Extract
lats = city_data_pd["Lat"]
max_temp =city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]
city_data_pd.to_csv(output_data_file, index_label = "City_ID")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  542.000000  542.000000  542.000000  542.000000  542.000000  542.000000
# mean    20.857203   17.672444   47.347066   75.341328   55.214022    8.381587
# std     33.285161   93.427057   32.067676   18.023083   38.533495    6.040464
# min    -54.800000 -179.166700  -43.940000    1.000000    0.000000    0.540000
# 25%     -7.275525  -67.496475   27.075000   67.250000   18.000000    3.677500
# 50%     26.644050   20.208700   57.000000   80.000000   75.000000    6.910000
# 75%     48.906275  100.047650   73.970000   88.000000   90.000000   11.500000
# max     78.218600  179.316700   92.370000  100.000000  100.000000   37.780000
#
#                Date
# count  5.420000e+02
# mean   1.610408e+09
# std    6.857037e+01
# min    1.610408e+09
# 25%    1.610408e+09
# 50%    1.610408e+09
# 75%    1.610408e+09
# max    1.610408e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Create plot
plt.scatter(lats, max_temp, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Max Temp.png")
plt.show()

# %% [markdown]
# City Latitude vs. Max Temperature plot shows the maximum temperature recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Create plot
plt.scatter(lats, humidity, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Humidity ({today})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Humidity.png")

# %% [markdown]
# City Latitude vs. Humidity plot shows the humidity percentage recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Create plot
plt.scatter(lats, cloudiness, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Cloudiness ({today})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-5,105)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Cloudiness.png")

# %% [markdown]
# City Latitude vs. Cloudiness plot shows the cloudiness percentage recorded at the latitude of the city it was taken from.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Create plot
plt.scatter(lats,wind_speed, facecolor = "steelblue", edgecolor = "black")
plt.title(f"City Latitude vs. Wind Speed ({today})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,50)
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.5)

#Save the image
plt.savefig("output_data/City Lat vs Wind Speed.png")

# %% [markdown]
# City Latitude vs. Wind Speed plot shows the wind speed recorded in miles per hour at the latitude of the city it was taken from.

# %% [markdown]
# ## Linear Regression

# %%
#Create northern and southern hemisphere dataframes
northern_hemisphere = city_data_pd[city_data_pd["Lat"] >= 0]
southern_hemisphere = city_data_pd[city_data_pd["Lat"] < 0]

#Define functions for linear regression and scatter plot
def linear_regression(x,y,title,text_coordinates):
    print(f"The r-squared is : {round(st.pearsonr(x,y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x = " + str(round(intercept,2))
    plt.scatter(x,y, alpha=0.5, edgecolor='black')
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize = 15, color = "red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue ** 2}")
    print(f"The line equation is: {line_eq}")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Max Temp"]
plt.title(f'Northern Hemisphere: City Latitude vs. Max Temp ({today})')
linear_regression(x,y,'Max Temp (F)',(0,-40))

plt.savefig("output_data/Northern_MaxTempVsLat_Regression.png")
# Out:
# The r-squared is : -0.84
# The r-value is: 0.7110787712011183
# The line equation is: y = -1.36x = 88.96

# %% [markdown]
# There is a strong negative correlation of higher temperatures at latitudes closer to the equator and cooler temperatures as you increase north.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Max Temp"]
plt.title(f'Southern Hemisphere: City Latitude vs. Max Temp ({today})')
linear_regression(x,y,'Max Temp (F)',(-30,50))
plt.savefig("output_data/ Southern Max Temp Linear Regression.png")
# Out:
# The r-squared is : 0.61
# The r-value is: 0.3689847445134636
# The line equation is: y = 0.38x = 82.59

# %% [markdown]
# There is a moderate positive correlation of the temperature decreasing the farther south from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Humidity"]
plt.title(f'Northern Hemisphere: City Latitude vs. Humidity ({today})')
linear_regression(x,y,'Humdity (%)',(40,20))
plt.savefig("output_data/Northern Humidity Linear Regression.png")
# Out:
# The r-squared is : 0.35
# The r-value is: 0.12519544669991578
# The line equation is: y = 0.35x = 62.0

# %% [markdown]
# There is a weak positive correlation as humidity increases the farther north you go.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Humidity"]
plt.title(f'Southern Hemisphere: City Latitude vs. Humidity ({today})')
linear_regression(x,y,'Humidity (%)',(-25,20))
plt.savefig("output_data/Southern Humidity Linear Regression.png")
# Out:
# The r-squared is : 0.51
# The r-value is: 0.2618671805228352
# The line equation is: y = 0.56x = 86.68

# %% [markdown]
# There is a very weak positive correlation between humidity and the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Cloudiness"]
plt.title(f'Northern Hemisphere: City Latitude vs. Cloudiness ({today})')
linear_regression(x,y,'Cloudiness (%)',(40,10))
plt.savefig("output_data/Northern Cloudiness Linear Regression.png")
# Out:
# The r-squared is : 0.21
# The r-value is: 0.042146449433927785
# The line equation is: y = 0.41x = 39.27

# %% [markdown]
# There is a positive correlation shown in the plot, however the plot also shows cloudiness at all percentages in most of the latitudes.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Cloudiness"]
plt.title(f'Southern Hemisphere: City Latitude vs. Cloudiness ({today})')
linear_regression(x,y,'Cloudiness (%)',(-55,22))
plt.savefig("output_data/Southern Cloudiness Linear Regression.png")
# Out:
# The r-squared is : 0.24
# The r-value is: 0.056165918510928524
# The line equation is: y = 0.67x = 69.6

# %% [markdown]
# There is a positive correlation shown again, however the graph shows again most cloudiness percentages at most of the latitudes. This is also confirmed with the northern hemisphere and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_hemisphere["Lat"]
y = northern_hemisphere["Wind Speed"]
plt.title(f'Northern Hemisphere: City Latitude vs. Wind Speed ({today})')
linear_regression(x,y,'Wind Speed (mph)',(10,30))
plt.savefig("output_data/Northern Wind Speed Linear Regression.png")
# Out:
# The r-squared is : 0.04
# The r-value is: 0.001594462400920881
# The line equation is: y = 0.01x = 7.87

# %% [markdown]
# There is a very weak correlation between moving north and wind speed.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_hemisphere["Lat"]
y = southern_hemisphere["Wind Speed"]
plt.title(f'Southern Hemisphere: City Latitude vs. Wind Speed ({today})')
linear_regression(x,y,'Wind Speed (mph)',(-55,22))
plt.savefig("output_data/Southern Wind Speed Linear Regression.png")
# Out:
# The r-squared is : -0.18
# The r-value is: 0.0331551635289572
# The line equation is: y = -0.08x = 6.69

# %% [markdown]
# There is a negative correlation between moving farther south from the equator and wind speed.
